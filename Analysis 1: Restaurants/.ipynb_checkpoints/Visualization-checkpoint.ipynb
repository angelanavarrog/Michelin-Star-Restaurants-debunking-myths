# %%
import pandas as pd  #used
import numpy as np  #used
import json
import seaborn as sns  #used
import matplotlib as plt  #used
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from cartoframes.viz import Map, Layer, popup_element
from cartoframes.data.services import Geocoding
import folium #used
from folium import Choropleth, Circle, Marker, Icon, Map #used
from folium.plugins import HeatMap, MarkerCluster #used

import bokeh
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
from bokeh.sampledata.autompg import autompg
import requests 
from bs4 import BeautifulSoup
from tabulate import tabulate

# %%
restaurants = "../output/restaurants2.geojson"
map_data = gpd.read_file(restaurants)
map_data.head()
# Out:
#          restaurant michelin_stars                      city province  \
# 0            Mantua              1      Jerez de la Frontera    Cadiz
# 1  Lu Cocina y Alma              1      Jerez de la Frontera    Cadiz
# 2         Aponiente              3  El Puerto de Santa Maria    Cadiz
# 3          Alevante              1         Novo Sancti Petri    Cadiz
# 4           Abantal              1                   Sevilla  Sevilla
#
#       region            coordenates   latitude  longitude price_menu_1  \
# 0  Andalucia  36.6874279,-6.1380431  36.687428  -6.138043           75
# 1  Andalucia  36.6876237,-6.1376777  36.687624  -6.137678           90
# 2  Andalucia   36.605854,-6.2157528  36.605854  -6.215753          215
# 3  Andalucia  36.3442398,-6.1616944  36.344240  -6.161694          115
# 4  Andalucia    37.3879127,-5.98587  37.387913  -5.985870           80
#
#   price_menu_2 price_average type_of_cooking1 type_of_cooking2  \
# 0         90.0          82.5          Moderna
# ...

# %%
restaurants = pd.read_csv("../output/restaurants.csv", encoding = "ISO-8859-1")

# %%
restaurants.head()
# Out:
#          restaurant  michelin_stars                      city province  \
# 0            Mantua               1      Jerez de la Frontera    Cadiz
# 1  Lu Cocina y Alma               1      Jerez de la Frontera    Cadiz
# 2         Aponiente               3  El Puerto de Santa Maria    Cadiz
# 3          Alevante               1         Novo Sancti Petri    Cadiz
# 4           Abantal               1                   Sevilla  Sevilla
#
#       region coast_province            coordenates   latitude  longitude  \
# 0  Andalucia            Yes  36.6874279,-6.1380431  36.687428  -6.138043
# 1  Andalucia            Yes  36.6876237,-6.1376777  36.687624  -6.137678
# 2  Andalucia            Yes   36.605854,-6.2157528  36.605854  -6.215753
# 3  Andalucia            Yes  36.3442398,-6.1616944  36.344240  -6.161694
# 4  Andalucia             No    37.3879127,-5.98587  37.387913  -5.985870
#
#    price_menu_1  price_menu_2  price_average type_of_cooking1  \
# ...

# %% [markdown]
# ## 1. Convert to geodataframe

# %%
import shapely
shapely.speedups.enable()

# %% [markdown]
# ## 2. Restaurants location

# %%
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(figsize=(10, 10))
 
# Control del título y los ejes
ax.set_title('Restaurantes Estrella Michelin España, 2020', 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#4873ab'})
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Mostrar el mapa finalizado
map_data.plot(column = 'michelin_stars', cmap='plasma', ax=ax, zorder=5)
# Out:
# <AxesSubplot:title={'center':'Restaurantes Estrella Michelin España, 2020'}, xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# **Mapa en el que se localiza la totalidad de restaurantes Estrella Michelin en el mapa de España**

# %%
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(figsize = (10, 10))
 
# Control del encuadre (área geográfica) del mapa
ax.axis([-12, 5, 32, 48])
 
# Control del título y los ejes
ax.set_title('Restaurantes Estrella Michelin España, 2020', 
             pad = 20, 
             fontdict = {'fontsize':20, 'color': '#4873ab'})
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
 
# Añadir la leyenda separada del mapa
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size = "5%", pad = 0.2)
 
# Generar y cargar el mapa
map_data.plot(column = 'michelin_stars', cmap = 'plasma', ax=ax,
              legend = True, cax = cax, zorder = 5)
# Out:
# <AxesSubplot:title={'center':'Restaurantes Estrella Michelin España, 2020'}, xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# ## 2. Visualization

# %% [markdown]
# #### Michelin Star restaurant per Spanish region

# %%
restaurants["region"].value_counts()
# Out:
# Cataluna              54
# C.Valenciana          23
# Pais Vasco            22
# C.Madrid              22
# Andalucia             17
# Castilla y Leon       13
# Galicia               13
# Islas Baleares        10
# Asturias               8
# Castilla la Mancha     7
# Aragon                 7
# Islas Canarias         5
# La Rioja               5
# Cantabria              5
# Navarra                4
# Murcia                 3
# Galica                 1
# Extremadura            1
# Name: region, dtype: int64

# %%
restaurants.sort_values("region", ascending = True).groupby(['region']).sum()['michelin_stars'].plot(kind='bar',color = 'red',alpha = 0.5,figsize = (14, 10))
ax.set_title('Spanish Michelin Star Restaurants per region ',
             fontdict = {'fontsize':30, 'color': '#4873ab'})
# Out:
# Text(0.5, 1.0, 'Spanish Michelin Star Restaurants per region ')

# %% [markdown]
# ####

# %%
restaurants.groupby(['region']).count()['restaurant'].plot(kind='bar',color = 'red',alpha = 0.5, figsize = (10, 10))
# Out:
# <AxesSubplot:xlabel='region'>

# %%
restaurants["province"].value_counts()
# Out:
# Barcelona                 29
# Madrid                    22
# Gerona                    16
# Alicante                  14
# Guipuzcua                 12
# Vizcaya                   11
# Islas Baleares            10
# Asturias                   8
# Tarragona                  7
# Valencia                   7
# Pontevedra                 7
# Malaga                     6
# Santander                  5
# Valladolid                 5
# La Coruna                  5
# La Rioja                   5
# Cadiz                      4
# Navarra                    4
# Jaen                       4
# Huesca                     4
# Santa Cruz de Tenerife     3
# Soria                      3
# Murcia                     3
# Leon                       3
# Toledo                     3
# Las Palmas                 2
# Castellon                  2
# Orense                     2
# Salamanca                  2
# Lerida                     2
# Zaragoza                   2
# Cuenca                     1
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 10))
ax.set_title('Restaurantes por comunidad autónoma 2020', 
             pad = 20, 
             fontdict = {'fontsize':15, 'color': '#4873aa'})
sns.barplot(x = "michelin_stars", y = "region",hue = "michelin_stars", data = restaurants, ax = ax);

# %%
fig, ax = plt.subplots(figsize = (30,10))
ax.set_title('Restaurantes por comunidad autónoma 2020', 
             pad = 20, 
             fontdict = {'fontsize':30, 'color': '#4873aa'})
sns.histplot(x = restaurants.region, hue = restaurants.michelin_stars, cumulative = False)
# Out:
# <AxesSubplot:title={'center':'Restaurantes por comunidad autónoma 2020'}, xlabel='region', ylabel='Count'>

# %%
map_final = folium.Map (location = [40.7592189,-73.9783534],zoom_start = 15, min_lon = - 180, max_lon = 180, attr = 'Mapbox attribution')
